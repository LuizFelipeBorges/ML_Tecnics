# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import pandas as pd
import numpy as np

# %%
data = pd.read_csv("sample_data/california_housing_train.csv")
data.head()
# Out:
#    longitude  latitude  ...  median_income  median_house_value
# 0    -114.31     34.19  ...         1.4936             66900.0
# 1    -114.47     34.40  ...         1.8200             80100.0
# 2    -114.56     33.69  ...         1.6509             85700.0
# 3    -114.57     33.64  ...         3.1917             73400.0
# 4    -114.57     33.57  ...         1.9250             65500.0
#
# [5 rows x 9 columns]

# %%
data_test = pd.read_csv("sample_data/california_housing_test.csv")
data_test.head()
# Out:
#    longitude  latitude  ...  median_income  median_house_value
# 0    -122.05     37.37  ...         6.6085            344700.0
# 1    -118.30     34.26  ...         3.5990            176500.0
# 2    -117.81     33.78  ...         5.7934            270500.0
# 3    -118.36     33.82  ...         6.1359            330000.0
# 4    -119.67     36.33  ...         2.9375             81700.0
#
# [5 rows x 9 columns]

# %%
X = data.drop('median_house_value', axis=1)
y = data['median_house_value']

# %%
class Net(nn.Module):

  def __init__(self):
    super(Net, self).__init__()

    self.fc1 = nn.Linear(8, 100)
    self.fc2 = nn.Linear(100, 100)
    self.out = nn.Linear(100, 1)

  def forward(self, x):
    x = F.normalize(x)
    x = F.relu(self.fc1(x))
    x = F.relu(self.fc2(x))
    
    y = self.out(x)

    return y

# %%
net = Net()

# %%
X_tensor = torch.from_numpy(data.values[:, :-1]).float()
y_tensor = torch.from_numpy(data.values[:, -1]).float()

y_tensor = torch.log(y_tensor)

# %%
X_test_tensor = torch.from_numpy(data_test.values[:, :-1]).float()
y_test = data_test.values[:, -1]

# %%
import torch.optim as optim
optimizer = optim.Adam(net.parameters(), lr=0.001)

# %%
criterion = nn.MSELoss()

# %%
for i in range(1001):
  optimizer.zero_grad()
  prediction = net(X_tensor)
  loss = criterion(prediction, y_tensor)
  loss.backward()
  optimizer.step()

  prediction2 = torch.exp(net(X_tensor))
  loss = criterion(prediction2, torch.exp(y_tensor))
  print(i," de 1000")
  print("Monitor de loss:", torch.sqrt(loss))
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/loss.py:445: UserWarning: Using a target size (torch.Size([17000])) that is different to the input size (torch.Size([17000, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# 0  de 1000
# Monitor de loss: tensor(140297.3906, grad_fn=<SqrtBackward>)
# 1  de 1000
# Monitor de loss: tensor(136732.7969, grad_fn=<SqrtBackward>)
# 2  de 1000
# Monitor de loss: tensor(134945.1562, grad_fn=<SqrtBackward>)
# 3  de 1000
# Monitor de loss: tensor(134385.0156, grad_fn=<SqrtBackward>)
# 4  de 1000
# Monitor de loss: tensor(134606.5312, grad_fn=<SqrtBackward>)
# 5  de 1000
# Monitor de loss: tensor(135297.8750, grad_fn=<SqrtBackward>)
# 6  de 1000
# Monitor de loss: tensor(136207.3438, grad_fn=<SqrtBackward>)
# 7  de 1000
# Monitor de loss: tensor(137160.9844, grad_fn=<SqrtBackward>)
# 8  de 1000
# Monitor de loss: tensor(138047.5938, grad_fn=<SqrtBackward>)
# 9  de 1000
# Monitor de loss: tensor(138798.1875, grad_fn=<SqrtBackward>)
# 10  de 1000
# Monitor de loss: tensor(139370.6875, grad_fn=<SqrtBackward>)
# 11  de 1000
# Monitor de loss: tensor(139750.4688, grad_fn=<SqrtBackward>)
# 12  de 1000
# Monitor de loss: tensor(139926.4531, grad_fn=<SqrtBackward>)
# 13  de 1000
# Monitor de loss: tensor(139903.6250, grad_fn=<SqrtBackward>)
# 14  de 1000
# Monitor de loss: tensor(139699.1406, grad_fn=<SqrtBackward>)
# 15  de 1000
# Monitor de loss: tensor(139328.9219, grad_fn=<SqrtBackward>)
# 16  de 1000
# Monitor de loss: tensor(138827.1719, grad_fn=<SqrtBackward>)
# 17  de 1000
# Monitor de loss: tensor(138215.2188, grad_fn=<SqrtBackward>)
# 18  de 1000
# Monitor de loss: tensor(137524.5625, grad_fn=<SqrtBackward>)
# 19  de 1000
# Monitor de loss: tensor(136782.6406, grad_fn=<SqrtBackward>)
# 20  de 1000
# Monitor de loss: tensor(136018.3906, grad_fn=<SqrtBackward>)
# 21  de 1000
# Monitor de loss: tensor(135251.1250, grad_fn=<SqrtBackward>)
# 22  de 1000
# Monitor de loss: tensor(134520.3438, grad_fn=<SqrtBackward>)
# 23  de 1000
# Monitor de loss: tensor(133828.8906, grad_fn=<SqrtBackward>)
# 24  de 1000
# Monitor de loss: tensor(133213.4688, grad_fn=<SqrtBackward>)
# 25  de 1000
# Monitor de loss: tensor(132668.8906, grad_fn=<SqrtBackward>)
# 26  de 1000
# Monitor de loss: tensor(132216.9219, grad_fn=<SqrtBackward>)
# 27  de 1000
# Monitor de loss: tensor(131837.4531, grad_fn=<SqrtBackward>)
# 28  de 1000
# Monitor de loss: tensor(131552.1250, grad_fn=<SqrtBackward>)
# 29  de 1000
# Monitor de loss: tensor(131336.0938, grad_fn=<SqrtBackward>)
# 30  de 1000
# Monitor de loss: tensor(131186.3125, grad_fn=<SqrtBackward>)
# 31  de 1000
# Monitor de loss: tensor(131089.1406, grad_fn=<SqrtBackward>)
# 32  de 1000
# Monitor de loss: tensor(131028.6641, grad_fn=<SqrtBackward>)
# 33  de 1000
# Monitor de loss: tensor(130995.9453, grad_fn=<SqrtBackward>)
# 34  de 1000
# Monitor de loss: tensor(130980.5469, grad_fn=<SqrtBackward>)
# 35  de 1000
# Monitor de loss: tensor(130959.9531, grad_fn=<SqrtBackward>)
# 36  de 1000
# Monitor de loss: tensor(130931.9688, grad_fn=<SqrtBackward>)
# 37  de 1000
# Monitor de loss: tensor(130894.4062, grad_fn=<SqrtBackward>)
# 38  de 1000
# Monitor de loss: tensor(130839.0781, grad_fn=<SqrtBackward>)
# 39  de 1000
# Monitor de loss: tensor(130765.2656, grad_fn=<SqrtBackward>)
# 40  de 1000
# Monitor de loss: tensor(130674.7734, grad_fn=<SqrtBackward>)
# 41  de 1000
# Monitor de loss: tensor(130569.6797, grad_fn=<SqrtBackward>)
# 42  de 1000
# Monitor de loss: tensor(130454.9219, grad_fn=<SqrtBackward>)
# 43  de 1000
# Monitor de loss: tensor(130332.9297, grad_fn=<SqrtBackward>)
# 44  de 1000
# Monitor de loss: tensor(130210.4844, grad_fn=<SqrtBackward>)
# 45  de 1000
# Monitor de loss: tensor(130089.2891, grad_fn=<SqrtBackward>)
# 46  de 1000
# Monitor de loss: tensor(129971.8125, grad_fn=<SqrtBackward>)
# 47  de 1000
# Monitor de loss: tensor(129866.7031, grad_fn=<SqrtBackward>)
# 48  de 1000
# Monitor de loss: tensor(129765.2656, grad_fn=<SqrtBackward>)
# 49  de 1000
# Monitor de loss: tensor(129678.0547, grad_fn=<SqrtBackward>)
# 50  de 1000
# Monitor de loss: tensor(129601.3672, grad_fn=<SqrtBackward>)
# 51  de 1000
# Monitor de loss: tensor(129541.4453, grad_fn=<SqrtBackward>)
# 52  de 1000
# Monitor de loss: tensor(129490.4219, grad_fn=<SqrtBackward>)
# 53  de 1000
# Monitor de loss: tensor(129448.5156, grad_fn=<SqrtBackward>)
# 54  de 1000
# Monitor de loss: tensor(129413.7891, grad_fn=<SqrtBackward>)
# 55  de 1000
# Monitor de loss: tensor(129381.8828, grad_fn=<SqrtBackward>)
# 56  de 1000
# Monitor de loss: tensor(129353.2344, grad_fn=<SqrtBackward>)
# 57  de 1000
# Monitor de loss: tensor(129325.6797, grad_fn=<SqrtBackward>)
# 58  de 1000
# Monitor de loss: tensor(129300.5078, grad_fn=<SqrtBackward>)
# 59  de 1000
# Monitor de loss: tensor(129270.4219, grad_fn=<SqrtBackward>)
# 60  de 1000
# Monitor de loss: tensor(129241.8594, grad_fn=<SqrtBackward>)
# 61  de 1000
# Monitor de loss: tensor(129209.0547, grad_fn=<SqrtBackward>)
# 62  de 1000
# Monitor de loss: tensor(129168.8672, grad_fn=<SqrtBackward>)
# 63  de 1000
# Monitor de loss: tensor(129125.0234, grad_fn=<SqrtBackward>)
# 64  de 1000
# Monitor de loss: tensor(129075.4141, grad_fn=<SqrtBackward>)
# 65  de 1000
# Monitor de loss: tensor(129019.5938, grad_fn=<SqrtBackward>)
# 66  de 1000
# Monitor de loss: tensor(128959.5938, grad_fn=<SqrtBackward>)
# 67  de 1000
# Monitor de loss: tensor(128892.9531, grad_fn=<SqrtBackward>)
# 68  de 1000
# Monitor de loss: tensor(128823.1484, grad_fn=<SqrtBackward>)
# 69  de 1000
# Monitor de loss: tensor(128753.5391, grad_fn=<SqrtBackward>)
# 70  de 1000
# Monitor de loss: tensor(128681.8281, grad_fn=<SqrtBackward>)
# 71  de 1000
# Monitor de loss: tensor(128608.9844, grad_fn=<SqrtBackward>)
# 72  de 1000
# Monitor de loss: tensor(128533.8281, grad_fn=<SqrtBackward>)
# 73  de 1000
# Monitor de loss: tensor(128458.9219, grad_fn=<SqrtBackward>)
# 74  de 1000
# Monitor de loss: tensor(128384.4688, grad_fn=<SqrtBackward>)
# 75  de 1000
# Monitor de loss: tensor(128310.7578, grad_fn=<SqrtBackward>)
# 76  de 1000
# Monitor de loss: tensor(128240.6328, grad_fn=<SqrtBackward>)
# 77  de 1000
# Monitor de loss: tensor(128169.2578, grad_fn=<SqrtBackward>)
# 78  de 1000
# Monitor de loss: tensor(128098.4219, grad_fn=<SqrtBackward>)
# 79  de 1000
# Monitor de loss: tensor(128027.1953, grad_fn=<SqrtBackward>)
# 80  de 1000
# Monitor de loss: tensor(127960.1172, grad_fn=<SqrtBackward>)
# 81  de 1000
# Monitor de loss: tensor(127894.6406, grad_fn=<SqrtBackward>)
# 82  de 1000
# Monitor de loss: tensor(127831.5547, grad_fn=<SqrtBackward>)
# 83  de 1000
# Monitor de loss: tensor(127770.3594, grad_fn=<SqrtBackward>)
# 84  de 1000
# Monitor de loss: tensor(127713.2344, grad_fn=<SqrtBackward>)
# 85  de 1000
# Monitor de loss: tensor(127655.2812, grad_fn=<SqrtBackward>)
# 86  de 1000
# Monitor de loss: tensor(127601.2969, grad_fn=<SqrtBackward>)
# 87  de 1000
# Monitor de loss: tensor(127548.9688, grad_fn=<SqrtBackward>)
# 88  de 1000
# Monitor de loss: tensor(127497.5938, grad_fn=<SqrtBackward>)
# 89  de 1000
# Monitor de loss: tensor(127447.3984, grad_fn=<SqrtBackward>)
# 90  de 1000
# Monitor de loss: tensor(127400.6250, grad_fn=<SqrtBackward>)
# 91  de 1000
# Monitor de loss: tensor(127354.9922, grad_fn=<SqrtBackward>)
# 92  de 1000
# Monitor de loss: tensor(127311.3906, grad_fn=<SqrtBackward>)
# 93  de 1000
# Monitor de loss: tensor(127268.2578, grad_fn=<SqrtBackward>)
# 94  de 1000
# Monitor de loss: tensor(127228.2734, grad_fn=<SqrtBackward>)
# 95  de 1000
# Monitor de loss: tensor(127188.2344, grad_fn=<SqrtBackward>)
# 96  de 1000
# Monitor de loss: tensor(127150.1328, grad_fn=<SqrtBackward>)
# 97  de 1000
# Monitor de loss: tensor(127112.4062, grad_fn=<SqrtBackward>)
# 98  de 1000
# Monitor de loss: tensor(127075.7500, grad_fn=<SqrtBackward>)
# 99  de 1000
# Monitor de loss: tensor(127038.6328, grad_fn=<SqrtBackward>)
# 100  de 1000
# Monitor de loss: tensor(127002.1641, grad_fn=<SqrtBackward>)
# 101  de 1000
# Monitor de loss: tensor(126965.0469, grad_fn=<SqrtBackward>)
# 102  de 1000
# Monitor de loss: tensor(126928.0469, grad_fn=<SqrtBackward>)
# 103  de 1000
# Monitor de loss: tensor(126890.5156, grad_fn=<SqrtBackward>)
# 104  de 1000
# Monitor de loss: tensor(126853.7344, grad_fn=<SqrtBackward>)
# 105  de 1000
# Monitor de loss: tensor(126816.4375, grad_fn=<SqrtBackward>)
# 106  de 1000
# Monitor de loss: tensor(126777.8125, grad_fn=<SqrtBackward>)
# 107  de 1000
# Monitor de loss: tensor(126739.4453, grad_fn=<SqrtBackward>)
# 108  de 1000
# Monitor de loss: tensor(126701.0312, grad_fn=<SqrtBackward>)
# 109  de 1000
# Monitor de loss: tensor(126661.1172, grad_fn=<SqrtBackward>)
# 110  de 1000
# Monitor de loss: tensor(126621.1797, grad_fn=<SqrtBackward>)
# 111  de 1000
# Monitor de loss: tensor(126582.1562, grad_fn=<SqrtBackward>)
# 112  de 1000
# Monitor de loss: tensor(126541.7188, grad_fn=<SqrtBackward>)
# 113  de 1000
# Monitor de loss: tensor(126501.6797, grad_fn=<SqrtBackward>)
# 114  de 1000
# Monitor de loss: tensor(126461.5156, grad_fn=<SqrtBackward>)
# 115  de 1000
# Monitor de loss: tensor(126421.1641, grad_fn=<SqrtBackward>)
# 116  de 1000
# Monitor de loss: tensor(126380.5703, grad_fn=<SqrtBackward>)
# 117  de 1000
# Monitor de loss: tensor(126339.6562, grad_fn=<SqrtBackward>)
# 118  de 1000
# Monitor de loss: tensor(126299.3438, grad_fn=<SqrtBackward>)
# 119  de 1000
# Monitor de loss: tensor(126259.9375, grad_fn=<SqrtBackward>)
# 120  de 1000
# Monitor de loss: tensor(126219.1406, grad_fn=<SqrtBackward>)
# 121  de 1000
# Monitor de loss: tensor(126178.4141, grad_fn=<SqrtBackward>)
# 122  de 1000
# Monitor de loss: tensor(126138.5547, grad_fn=<SqrtBackward>)
# 123  de 1000
# Monitor de loss: tensor(126100.4609, grad_fn=<SqrtBackward>)
# 124  de 1000
# Monitor de loss: tensor(126061.5469, grad_fn=<SqrtBackward>)
# 125  de 1000
# Monitor de loss: tensor(126023.8203, grad_fn=<SqrtBackward>)
# 126  de 1000
# Monitor de loss: tensor(125985.7891, grad_fn=<SqrtBackward>)
# 127  de 1000
# Monitor de loss: tensor(125947.8281, grad_fn=<SqrtBackward>)
# 128  de 1000
# Monitor de loss: tensor(125911.9688, grad_fn=<SqrtBackward>)
# 129  de 1000
# Monitor de loss: tensor(125875.0391, grad_fn=<SqrtBackward>)
# 130  de 1000
# Monitor de loss: tensor(125838.7109, grad_fn=<SqrtBackward>)
# 131  de 1000
# Monitor de loss: tensor(125801.8281, grad_fn=<SqrtBackward>)
# 132  de 1000
# Monitor de loss: tensor(125767.4219, grad_fn=<SqrtBackward>)
# 133  de 1000
# Monitor de loss: tensor(125732.6016, grad_fn=<SqrtBackward>)
# 134  de 1000
# Monitor de loss: tensor(125697.8281, grad_fn=<SqrtBackward>)
# 135  de 1000
# Monitor de loss: tensor(125665.3594, grad_fn=<SqrtBackward>)
# 136  de 1000
# Monitor de loss: tensor(125632.6016, grad_fn=<SqrtBackward>)
# 137  de 1000
# Monitor de loss: tensor(125600.0078, grad_fn=<SqrtBackward>)
# 138  de 1000
# Monitor de loss: tensor(125569., grad_fn=<SqrtBackward>)
# 139  de 1000
# Monitor de loss: tensor(125537.5625, grad_fn=<SqrtBackward>)
# 140  de 1000
# Monitor de loss: tensor(125505.5781, grad_fn=<SqrtBackward>)
# 141  de 1000
# Monitor de loss: tensor(125473.6953, grad_fn=<SqrtBackward>)
# 142  de 1000
# Monitor de loss: tensor(125443.4453, grad_fn=<SqrtBackward>)
# 143  de 1000
# Monitor de loss: tensor(125412.1484, grad_fn=<SqrtBackward>)
# 144  de 1000
# Monitor de loss: tensor(125381.5625, grad_fn=<SqrtBackward>)
# 145  de 1000
# Monitor de loss: tensor(125351.3906, grad_fn=<SqrtBackward>)
# 146  de 1000
# Monitor de loss: tensor(125322.2422, grad_fn=<SqrtBackward>)
# 147  de 1000
# Monitor de loss: tensor(125292.4453, grad_fn=<SqrtBackward>)
# 148  de 1000
# Monitor de loss: tensor(125262.4453, grad_fn=<SqrtBackward>)
# 149  de 1000
# Monitor de loss: tensor(125233.0781, grad_fn=<SqrtBackward>)
# 150  de 1000
# Monitor de loss: tensor(125203.5312, grad_fn=<SqrtBackward>)
# 151  de 1000
# Monitor de loss: tensor(125175.7344, grad_fn=<SqrtBackward>)
# 152  de 1000
# Monitor de loss: tensor(125147.3984, grad_fn=<SqrtBackward>)
# 153  de 1000
# Monitor de loss: tensor(125118.6953, grad_fn=<SqrtBackward>)
# 154  de 1000
# Monitor de loss: tensor(125090.3203, grad_fn=<SqrtBackward>)
# 155  de 1000
# Monitor de loss: tensor(125060.7266, grad_fn=<SqrtBackward>)
# 156  de 1000
# Monitor de loss: tensor(125031.6797, grad_fn=<SqrtBackward>)
# 157  de 1000
# Monitor de loss: tensor(125003.5000, grad_fn=<SqrtBackward>)
# 158  de 1000
# Monitor de loss: tensor(124975.8281, grad_fn=<SqrtBackward>)
# 159  de 1000
# Monitor de loss: tensor(124947.6250, grad_fn=<SqrtBackward>)
# 160  de 1000
# Monitor de loss: tensor(124919.9609, grad_fn=<SqrtBackward>)
# 161  de 1000
# Monitor de loss: tensor(124892.8594, grad_fn=<SqrtBackward>)
# 162  de 1000
# Monitor de loss: tensor(124866.0859, grad_fn=<SqrtBackward>)
# 163  de 1000
# Monitor de loss: tensor(124838.1328, grad_fn=<SqrtBackward>)
# 164  de 1000
# Monitor de loss: tensor(124810.3828, grad_fn=<SqrtBackward>)
# 165  de 1000
# Monitor de loss: tensor(124781.9609, grad_fn=<SqrtBackward>)
# 166  de 1000
# Monitor de loss: tensor(124755.3750, grad_fn=<SqrtBackward>)
# 167  de 1000
# Monitor de loss: tensor(124729.5078, grad_fn=<SqrtBackward>)
# 168  de 1000
# Monitor de loss: tensor(124703.3984, grad_fn=<SqrtBackward>)
# 169  de 1000
# Monitor de loss: tensor(124678.0156, grad_fn=<SqrtBackward>)
# 170  de 1000
# Monitor de loss: tensor(124653.0234, grad_fn=<SqrtBackward>)
# 171  de 1000
# Monitor de loss: tensor(124626.5703, grad_fn=<SqrtBackward>)
# 172  de 1000
# Monitor de loss: tensor(124599.5000, grad_fn=<SqrtBackward>)
# 173  de 1000
# Monitor de loss: tensor(124575.1172, grad_fn=<SqrtBackward>)
# 174  de 1000
# Monitor de loss: tensor(124550.8125, grad_fn=<SqrtBackward>)
# 175  de 1000
# Monitor de loss: tensor(124526.8125, grad_fn=<SqrtBackward>)
# 176  de 1000
# Monitor de loss: tensor(124501.3672, grad_fn=<SqrtBackward>)
# 177  de 1000
# Monitor de loss: tensor(124476.4922, grad_fn=<SqrtBackward>)
# 178  de 1000
# Monitor de loss: tensor(124453.1406, grad_fn=<SqrtBackward>)
# 179  de 1000
# Monitor de loss: tensor(124428.8125, grad_fn=<SqrtBackward>)
# 180  de 1000
# Monitor de loss: tensor(124405.1484, grad_fn=<SqrtBackward>)
# 181  de 1000
# Monitor de loss: tensor(124380.9844, grad_fn=<SqrtBackward>)
# 182  de 1000
# Monitor de loss: tensor(124356.3672, grad_fn=<SqrtBackward>)
# 183  de 1000
# Monitor de loss: tensor(124332.7500, grad_fn=<SqrtBackward>)
# 184  de 1000
# Monitor de loss: tensor(124309.1406, grad_fn=<SqrtBackward>)
# 185  de 1000
# Monitor de loss: tensor(124286.9141, grad_fn=<SqrtBackward>)
# 186  de 1000
# Monitor de loss: tensor(124264.2969, grad_fn=<SqrtBackward>)
# 187  de 1000
# Monitor de loss: tensor(124241.9375, grad_fn=<SqrtBackward>)
# 188  de 1000
# Monitor de loss: tensor(124219.5938, grad_fn=<SqrtBackward>)
# 189  de 1000
# Monitor de loss: tensor(124197.9062, grad_fn=<SqrtBackward>)
# 190  de 1000
# Monitor de loss: tensor(124175.7734, grad_fn=<SqrtBackward>)
# 191  de 1000
# Monitor de loss: tensor(124153.7422, grad_fn=<SqrtBackward>)
# 192  de 1000
# Monitor de loss: tensor(124131.3125, grad_fn=<SqrtBackward>)
# 193  de 1000
# Monitor de loss: tensor(124109.7266, grad_fn=<SqrtBackward>)
# 194  de 1000
# Monitor de loss: tensor(124088.3359, grad_fn=<SqrtBackward>)
# 195  de 1000
# Monitor de loss: tensor(124067.2891, grad_fn=<SqrtBackward>)
# 196  de 1000
# Monitor de loss: tensor(124046.2578, grad_fn=<SqrtBackward>)
# 197  de 1000
# Monitor de loss: tensor(124025.3203, grad_fn=<SqrtBackward>)
# 198  de 1000
# Monitor de loss: tensor(124003.8672, grad_fn=<SqrtBackward>)
# 199  de 1000
# Monitor de loss: tensor(123982.5547, grad_fn=<SqrtBackward>)
# 200  de 1000
# Monitor de loss: tensor(123962.0391, grad_fn=<SqrtBackward>)
# 201  de 1000
# Monitor de loss: tensor(123940.8359, grad_fn=<SqrtBackward>)
# 202  de 1000
# Monitor de loss: tensor(123920.4375, grad_fn=<SqrtBackward>)
# 203  de 1000
# Monitor de loss: tensor(123900.4922, grad_fn=<SqrtBackward>)
# 204  de 1000
# Monitor de loss: tensor(123879.9531, grad_fn=<SqrtBackward>)
# 205  de 1000
# Monitor de loss: tensor(123859.5312, grad_fn=<SqrtBackward>)
# 206  de 1000
# Monitor de loss: tensor(123839.6641, grad_fn=<SqrtBackward>)
# 207  de 1000
# Monitor de loss: tensor(123820.5703, grad_fn=<SqrtBackward>)
# 208  de 1000
# Monitor de loss: tensor(123799.6328, grad_fn=<SqrtBackward>)
# 209  de 1000
# Monitor de loss: tensor(123780.9844, grad_fn=<SqrtBackward>)
# 210  de 1000
# Monitor de loss: tensor(123762.3516, grad_fn=<SqrtBackward>)
# 211  de 1000
# Monitor de loss: tensor(123743.7734, grad_fn=<SqrtBackward>)
# 212  de 1000
# Monitor de loss: tensor(123724.0078, grad_fn=<SqrtBackward>)
# 213  de 1000
# Monitor de loss: tensor(123704.6562, grad_fn=<SqrtBackward>)
# 214  de 1000
# Monitor de loss: tensor(123685.2578, grad_fn=<SqrtBackward>)
# 215  de 1000
# Monitor de loss: tensor(123665.7344, grad_fn=<SqrtBackward>)
# 216  de 1000
# Monitor de loss: tensor(123646.4609, grad_fn=<SqrtBackward>)
# 217  de 1000
# Monitor de loss: tensor(123628.8359, grad_fn=<SqrtBackward>)
# 218  de 1000
# Monitor de loss: tensor(123611.1797, grad_fn=<SqrtBackward>)
# 219  de 1000
# Monitor de loss: tensor(123593.2578, grad_fn=<SqrtBackward>)
# 220  de 1000
# Monitor de loss: tensor(123575.4609, grad_fn=<SqrtBackward>)
# 221  de 1000
# Monitor de loss: tensor(123557.3281, grad_fn=<SqrtBackward>)
# 222  de 1000
# Monitor de loss: tensor(123539.8125, grad_fn=<SqrtBackward>)
# 223  de 1000
# Monitor de loss: tensor(123521.2812, grad_fn=<SqrtBackward>)
# 224  de 1000
# Monitor de loss: tensor(123504.0078, grad_fn=<SqrtBackward>)
# 225  de 1000
# Monitor de loss: tensor(123487.0547, grad_fn=<SqrtBackward>)
# 226  de 1000
# Monitor de loss: tensor(123469.0703, grad_fn=<SqrtBackward>)
# 227  de 1000
# Monitor de loss: tensor(123451.2969, grad_fn=<SqrtBackward>)
# 228  de 1000
# Monitor de loss: tensor(123435.4219, grad_fn=<SqrtBackward>)
# 229  de 1000
# Monitor de loss: tensor(123420.5078, grad_fn=<SqrtBackward>)
# 230  de 1000
# Monitor de loss: tensor(123403.4531, grad_fn=<SqrtBackward>)
# 231  de 1000
# Monitor de loss: tensor(123386.5859, grad_fn=<SqrtBackward>)
# 232  de 1000
# Monitor de loss: tensor(123370.6328, grad_fn=<SqrtBackward>)
# 233  de 1000
# Monitor de loss: tensor(123353.4297, grad_fn=<SqrtBackward>)
# 234  de 1000
# Monitor de loss: tensor(123339.1484, grad_fn=<SqrtBackward>)
# 235  de 1000
# Monitor de loss: tensor(123322.8125, grad_fn=<SqrtBackward>)
# 236  de 1000
# Monitor de loss: tensor(123306.4062, grad_fn=<SqrtBackward>)
# 237  de 1000
# Monitor de loss: tensor(123290.1484, grad_fn=<SqrtBackward>)
# 238  de 1000
# Monitor de loss: tensor(123274.1719, grad_fn=<SqrtBackward>)
# 239  de 1000
# Monitor de loss: tensor(123258.6172, grad_fn=<SqrtBackward>)
# 240  de 1000
# Monitor de loss: tensor(123243.3984, grad_fn=<SqrtBackward>)
# 241  de 1000
# Monitor de loss: tensor(123226.8672, grad_fn=<SqrtBackward>)
# 242  de 1000
# Monitor de loss: tensor(123210.7344, grad_fn=<SqrtBackward>)
# 243  de 1000
# Monitor de loss: tensor(123195.2344, grad_fn=<SqrtBackward>)
# 244  de 1000
# Monitor de loss: tensor(123178.9844, grad_fn=<SqrtBackward>)
# 245  de 1000
# Monitor de loss: tensor(123163.2734, grad_fn=<SqrtBackward>)
# 246  de 1000
# Monitor de loss: tensor(123149.1641, grad_fn=<SqrtBackward>)
# 247  de 1000
# Monitor de loss: tensor(123133.6641, grad_fn=<SqrtBackward>)
# 248  de 1000
# Monitor de loss: tensor(123119.3125, grad_fn=<SqrtBackward>)
# 249  de 1000
# Monitor de loss: tensor(123105.3672, grad_fn=<SqrtBackward>)
# 250  de 1000
# Monitor de loss: tensor(123091.1719, grad_fn=<SqrtBackward>)
# 251  de 1000
# Monitor de loss: tensor(123076.7109, grad_fn=<SqrtBackward>)
# 252  de 1000
# Monitor de loss: tensor(123061.5391, grad_fn=<SqrtBackward>)
# 253  de 1000
# Monitor de loss: tensor(123046.9609, grad_fn=<SqrtBackward>)
# 254  de 1000
# Monitor de loss: tensor(123031.9766, grad_fn=<SqrtBackward>)
# 255  de 1000
# Monitor de loss: tensor(123017.8516, grad_fn=<SqrtBackward>)
# 256  de 1000
# Monitor de loss: tensor(123004.3828, grad_fn=<SqrtBackward>)
# 257  de 1000
# Monitor de loss: tensor(122990.1328, grad_fn=<SqrtBackward>)
# 258  de 1000
# Monitor de loss: tensor(122976.2422, grad_fn=<SqrtBackward>)
# 259  de 1000
# Monitor de loss: tensor(122962.8750, grad_fn=<SqrtBackward>)
# 260  de 1000
# Monitor de loss: tensor(122948.8438, grad_fn=<SqrtBackward>)
# 261  de 1000
# Monitor de loss: tensor(122935.1562, grad_fn=<SqrtBackward>)
# 262  de 1000
# Monitor de loss: tensor(122921.6562, grad_fn=<SqrtBackward>)
# 263  de 1000
# Monitor de loss: tensor(122907.8672, grad_fn=<SqrtBackward>)
# 264  de 1000
# Monitor de loss: tensor(122894.9219, grad_fn=<SqrtBackward>)
# 265  de 1000
# Monitor de loss: tensor(122881.8516, grad_fn=<SqrtBackward>)
# 266  de 1000
# Monitor de loss: tensor(122869.3750, grad_fn=<SqrtBackward>)
# 267  de 1000
# Monitor de loss: tensor(122855.1094, grad_fn=<SqrtBackward>)
# 268  de 1000
# Monitor de loss: tensor(122841.1172, grad_fn=<SqrtBackward>)
# 269  de 1000
# Monitor de loss: tensor(122827.9609, grad_fn=<SqrtBackward>)
# 270  de 1000
# Monitor de loss: tensor(122815.0781, grad_fn=<SqrtBackward>)
# 271  de 1000
# Monitor de loss: tensor(122800.8359, grad_fn=<SqrtBackward>)
# 272  de 1000
# Monitor de loss: tensor(122788.5312, grad_fn=<SqrtBackward>)
# 273  de 1000
# Monitor de loss: tensor(122774.7188, grad_fn=<SqrtBackward>)
# 274  de 1000
# Monitor de loss: tensor(122761.8828, grad_fn=<SqrtBackward>)
# 275  de 1000
# Monitor de loss: tensor(122748.0938, grad_fn=<SqrtBackward>)
# 276  de 1000
# Monitor de loss: tensor(122735.0312, grad_fn=<SqrtBackward>)
# 277  de 1000
# Monitor de loss: tensor(122722.4453, grad_fn=<SqrtBackward>)
# 278  de 1000
# Monitor de loss: tensor(122710.6406, grad_fn=<SqrtBackward>)
# 279  de 1000
# Monitor de loss: tensor(122698.5859, grad_fn=<SqrtBackward>)
# 280  de 1000
# Monitor de loss: tensor(122684.7422, grad_fn=<SqrtBackward>)
# 281  de 1000
# Monitor de loss: tensor(122672.8281, grad_fn=<SqrtBackward>)
# 282  de 1000
# Monitor de loss: tensor(122660.7266, grad_fn=<SqrtBackward>)
# 283  de 1000
# Monitor de loss: tensor(122649.9453, grad_fn=<SqrtBackward>)
# 284  de 1000
# Monitor de loss: tensor(122638.0078, grad_fn=<SqrtBackward>)
# 285  de 1000
# Monitor de loss: tensor(122625.7656, grad_fn=<SqrtBackward>)
# 286  de 1000
# Monitor de loss: tensor(122615.0469, grad_fn=<SqrtBackward>)
# 287  de 1000
# Monitor de loss: tensor(122602.9375, grad_fn=<SqrtBackward>)
# 288  de 1000
# Monitor de loss: tensor(122591.3672, grad_fn=<SqrtBackward>)
# 289  de 1000
# Monitor de loss: tensor(122578.6406, grad_fn=<SqrtBackward>)
# 290  de 1000
# Monitor de loss: tensor(122567.7109, grad_fn=<SqrtBackward>)
# 291  de 1000
# Monitor de loss: tensor(122557.7891, grad_fn=<SqrtBackward>)
# 292  de 1000
# Monitor de loss: tensor(122546.8906, grad_fn=<SqrtBackward>)
# 293  de 1000
# Monitor de loss: tensor(122536.5000, grad_fn=<SqrtBackward>)
# 294  de 1000
# Monitor de loss: tensor(122525.6562, grad_fn=<SqrtBackward>)
# 295  de 1000
# Monitor de loss: tensor(122513.5234, grad_fn=<SqrtBackward>)
# 296  de 1000
# Monitor de loss: tensor(122501.9844, grad_fn=<SqrtBackward>)
# 297  de 1000
# Monitor de loss: tensor(122491.5312, grad_fn=<SqrtBackward>)
# 298  de 1000
# Monitor de loss: tensor(122481.4766, grad_fn=<SqrtBackward>)
# 299  de 1000
# Monitor de loss: tensor(122470.4219, grad_fn=<SqrtBackward>)
# 300  de 1000
# Monitor de loss: tensor(122459.3594, grad_fn=<SqrtBackward>)
# 301  de 1000
# Monitor de loss: tensor(122448.2109, grad_fn=<SqrtBackward>)
# 302  de 1000
# Monitor de loss: tensor(122437.6250, grad_fn=<SqrtBackward>)
# 303  de 1000
# Monitor de loss: tensor(122427.0469, grad_fn=<SqrtBackward>)
# 304  de 1000
# Monitor de loss: tensor(122417.0312, grad_fn=<SqrtBackward>)
# 305  de 1000
# Monitor de loss: tensor(122406.7344, grad_fn=<SqrtBackward>)
# 306  de 1000
# Monitor de loss: tensor(122397.2344, grad_fn=<SqrtBackward>)
# 307  de 1000
# Monitor de loss: tensor(122387.9688, grad_fn=<SqrtBackward>)
# 308  de 1000
# Monitor de loss: tensor(122376.9219, grad_fn=<SqrtBackward>)
# 309  de 1000
# Monitor de loss: tensor(122366.6875, grad_fn=<SqrtBackward>)
# 310  de 1000
# Monitor de loss: tensor(122357.3203, grad_fn=<SqrtBackward>)
# 311  de 1000
# Monitor de loss: tensor(122347.0391, grad_fn=<SqrtBackward>)
# 312  de 1000
# Monitor de loss: tensor(122337.3438, grad_fn=<SqrtBackward>)
# 313  de 1000
# Monitor de loss: tensor(122327.2656, grad_fn=<SqrtBackward>)
# 314  de 1000
# Monitor de loss: tensor(122316.6641, grad_fn=<SqrtBackward>)
# 315  de 1000
# Monitor de loss: tensor(122307.1484, grad_fn=<SqrtBackward>)
# 316  de 1000
# Monitor de loss: tensor(122296.3984, grad_fn=<SqrtBackward>)
# 317  de 1000
# Monitor de loss: tensor(122286.4141, grad_fn=<SqrtBackward>)
# 318  de 1000
# Monitor de loss: tensor(122276.7578, grad_fn=<SqrtBackward>)
# 319  de 1000
# Monitor de loss: tensor(122267.0859, grad_fn=<SqrtBackward>)
# 320  de 1000
# Monitor de loss: tensor(122258.1875, grad_fn=<SqrtBackward>)
# 321  de 1000
# Monitor de loss: tensor(122248.2578, grad_fn=<SqrtBackward>)
# 322  de 1000
# Monitor de loss: tensor(122238.4062, grad_fn=<SqrtBackward>)
# 323  de 1000
# Monitor de loss: tensor(122228.5625, grad_fn=<SqrtBackward>)
# 324  de 1000
# Monitor de loss: tensor(122219.6406, grad_fn=<SqrtBackward>)
# 325  de 1000
# Monitor de loss: tensor(122209.7188, grad_fn=<SqrtBackward>)
# 326  de 1000
# Monitor de loss: tensor(122199.7344, grad_fn=<SqrtBackward>)
# 327  de 1000
# Monitor de loss: tensor(122190.6094, grad_fn=<SqrtBackward>)
# 328  de 1000
# Monitor de loss: tensor(122180.1406, grad_fn=<SqrtBackward>)
# 329  de 1000
# Monitor de loss: tensor(122169.4688, grad_fn=<SqrtBackward>)
# 330  de 1000
# Monitor de loss: tensor(122160.3828, grad_fn=<SqrtBackward>)
# 331  de 1000
# Monitor de loss: tensor(122151.0078, grad_fn=<SqrtBackward>)
# 332  de 1000
# Monitor de loss: tensor(122141.9688, grad_fn=<SqrtBackward>)
# 333  de 1000
# Monitor de loss: tensor(122133.0938, grad_fn=<SqrtBackward>)
# 334  de 1000
# Monitor de loss: tensor(122124.5859, grad_fn=<SqrtBackward>)
# 335  de 1000
# Monitor de loss: tensor(122115.0547, grad_fn=<SqrtBackward>)
# 336  de 1000
# Monitor de loss: tensor(122105.3594, grad_fn=<SqrtBackward>)
# 337  de 1000
# Monitor de loss: tensor(122096.8438, grad_fn=<SqrtBackward>)
# 338  de 1000
# Monitor de loss: tensor(122087.9062, grad_fn=<SqrtBackward>)
# 339  de 1000
# Monitor de loss: tensor(122079.2266, grad_fn=<SqrtBackward>)
# 340  de 1000
# Monitor de loss: tensor(122069.6484, grad_fn=<SqrtBackward>)
# 341  de 1000
# Monitor de loss: tensor(122060.5703, grad_fn=<SqrtBackward>)
# 342  de 1000
# Monitor de loss: tensor(122051.9297, grad_fn=<SqrtBackward>)
# 343  de 1000
# Monitor de loss: tensor(122043.6094, grad_fn=<SqrtBackward>)
# 344  de 1000
# Monitor de loss: tensor(122034.6328, grad_fn=<SqrtBackward>)
# 345  de 1000
# Monitor de loss: tensor(122026.1719, grad_fn=<SqrtBackward>)
# 346  de 1000
# Monitor de loss: tensor(122017.6328, grad_fn=<SqrtBackward>)
# 347  de 1000
# Monitor de loss: tensor(122009.8203, grad_fn=<SqrtBackward>)
# 348  de 1000
# Monitor de loss: tensor(122001.5781, grad_fn=<SqrtBackward>)
# 349  de 1000
# Monitor de loss: tensor(121993.1328, grad_fn=<SqrtBackward>)
# 350  de 1000
# Monitor de loss: tensor(121984.9688, grad_fn=<SqrtBackward>)
# 351  de 1000
# Monitor de loss: tensor(121977.4922, grad_fn=<SqrtBackward>)
# 352  de 1000
# Monitor de loss: tensor(121969.1641, grad_fn=<SqrtBackward>)
# 353  de 1000
# Monitor de loss: tensor(121961.3203, grad_fn=<SqrtBackward>)
# 354  de 1000
# Monitor de loss: tensor(121953.3516, grad_fn=<SqrtBackward>)
# 355  de 1000
# Monitor de loss: tensor(121945.5234, grad_fn=<SqrtBackward>)
# 356  de 1000
# Monitor de loss: tensor(121937.7969, grad_fn=<SqrtBackward>)
# 357  de 1000
# Monitor de loss: tensor(121930.2578, grad_fn=<SqrtBackward>)
# 358  de 1000
# Monitor de loss: tensor(121921.9844, grad_fn=<SqrtBackward>)
# 359  de 1000
# Monitor de loss: tensor(121914.2578, grad_fn=<SqrtBackward>)
# 360  de 1000
# Monitor de loss: tensor(121906.1875, grad_fn=<SqrtBackward>)
# 361  de 1000
# Monitor de loss: tensor(121897.9141, grad_fn=<SqrtBackward>)
# 362  de 1000
# Monitor de loss: tensor(121890.4609, grad_fn=<SqrtBackward>)
# 363  de 1000
# Monitor de loss: tensor(121882.3516, grad_fn=<SqrtBackward>)
# 364  de 1000
# Monitor de loss: tensor(121874.0859, grad_fn=<SqrtBackward>)
# 365  de 1000
# Monitor de loss: tensor(121866.5859, grad_fn=<SqrtBackward>)
# 366  de 1000
# Monitor de loss: tensor(121859.0312, grad_fn=<SqrtBackward>)
# 367  de 1000
# Monitor de loss: tensor(121851.6484, grad_fn=<SqrtBackward>)
# 368  de 1000
# Monitor de loss: tensor(121844.5703, grad_fn=<SqrtBackward>)
# 369  de 1000
# Monitor de loss: tensor(121838.0234, grad_fn=<SqrtBackward>)
# 370  de 1000
# Monitor de loss: tensor(121829.4688, grad_fn=<SqrtBackward>)
# 371  de 1000
# Monitor de loss: tensor(121821.5859, grad_fn=<SqrtBackward>)
# 372  de 1000
# Monitor de loss: tensor(121814.2188, grad_fn=<SqrtBackward>)
# 373  de 1000
# Monitor de loss: tensor(121806.9062, grad_fn=<SqrtBackward>)
# 374  de 1000
# Monitor de loss: tensor(121800.5547, grad_fn=<SqrtBackward>)
# 375  de 1000
# Monitor de loss: tensor(121792.6562, grad_fn=<SqrtBackward>)
# 376  de 1000
# Monitor de loss: tensor(121785.8438, grad_fn=<SqrtBackward>)
# 377  de 1000
# Monitor de loss: tensor(121778.9844, grad_fn=<SqrtBackward>)
# 378  de 1000
# Monitor de loss: tensor(121771.9531, grad_fn=<SqrtBackward>)
# 379  de 1000
# Monitor de loss: tensor(121764.6406, grad_fn=<SqrtBackward>)
# 380  de 1000
# Monitor de loss: tensor(121757.9219, grad_fn=<SqrtBackward>)
# 381  de 1000
# Monitor de loss: tensor(121751.0312, grad_fn=<SqrtBackward>)
# 382  de 1000
# Monitor de loss: tensor(121743.7578, grad_fn=<SqrtBackward>)
# 383  de 1000
# Monitor de loss: tensor(121737.0547, grad_fn=<SqrtBackward>)
# 384  de 1000
# Monitor de loss: tensor(121730.4062, grad_fn=<SqrtBackward>)
# 385  de 1000
# Monitor de loss: tensor(121723.7344, grad_fn=<SqrtBackward>)
# 386  de 1000
# Monitor de loss: tensor(121717.0781, grad_fn=<SqrtBackward>)
# 387  de 1000
# Monitor de loss: tensor(121709.3828, grad_fn=<SqrtBackward>)
# 388  de 1000
# Monitor de loss: tensor(121702.8750, grad_fn=<SqrtBackward>)
# 389  de 1000
# Monitor de loss: tensor(121695.0859, grad_fn=<SqrtBackward>)
# 390  de 1000
# Monitor de loss: tensor(121688.4375, grad_fn=<SqrtBackward>)
# 391  de 1000
# Monitor de loss: tensor(121681.5469, grad_fn=<SqrtBackward>)
# 392  de 1000
# Monitor de loss: tensor(121674.3125, grad_fn=<SqrtBackward>)
# 393  de 1000
# Monitor de loss: tensor(121668.4141, grad_fn=<SqrtBackward>)
# 394  de 1000
# Monitor de loss: tensor(121661.0391, grad_fn=<SqrtBackward>)
# 395  de 1000
# Monitor de loss: tensor(121654.3672, grad_fn=<SqrtBackward>)
# 396  de 1000
# Monitor de loss: tensor(121647.8047, grad_fn=<SqrtBackward>)
# 397  de 1000
# Monitor de loss: tensor(121641.8438, grad_fn=<SqrtBackward>)
# 398  de 1000
# Monitor de loss: tensor(121634.5781, grad_fn=<SqrtBackward>)
# 399  de 1000
# Monitor de loss: tensor(121627.6016, grad_fn=<SqrtBackward>)
# 400  de 1000
# Monitor de loss: tensor(121621.0781, grad_fn=<SqrtBackward>)
# 401  de 1000
# Monitor de loss: tensor(121614.4688, grad_fn=<SqrtBackward>)
# 402  de 1000
# Monitor de loss: tensor(121607.0703, grad_fn=<SqrtBackward>)
# 403  de 1000
# Monitor de loss: tensor(121601.0078, grad_fn=<SqrtBackward>)
# 404  de 1000
# Monitor de loss: tensor(121593.8594, grad_fn=<SqrtBackward>)
# 405  de 1000
# Monitor de loss: tensor(121587.9844, grad_fn=<SqrtBackward>)
# 406  de 1000
# Monitor de loss: tensor(121582.0625, grad_fn=<SqrtBackward>)
# 407  de 1000
# Monitor de loss: tensor(121576.1172, grad_fn=<SqrtBackward>)
# 408  de 1000
# Monitor de loss: tensor(121570.4844, grad_fn=<SqrtBackward>)
# 409  de 1000
# Monitor de loss: tensor(121563.8203, grad_fn=<SqrtBackward>)
# 410  de 1000
# Monitor de loss: tensor(121556.8594, grad_fn=<SqrtBackward>)
# 411  de 1000
# Monitor de loss: tensor(121551.1719, grad_fn=<SqrtBackward>)
# 412  de 1000
# Monitor de loss: tensor(121544.5000, grad_fn=<SqrtBackward>)
# 413  de 1000
# Monitor de loss: tensor(121537.4062, grad_fn=<SqrtBackward>)
# 414  de 1000
# Monitor de loss: tensor(121531.1250, grad_fn=<SqrtBackward>)
# 415  de 1000
# Monitor de loss: tensor(121525.7969, grad_fn=<SqrtBackward>)
# 416  de 1000
# Monitor de loss: tensor(121519.9219, grad_fn=<SqrtBackward>)
# 417  de 1000
# Monitor de loss: tensor(121514.2422, grad_fn=<SqrtBackward>)
# 418  de 1000
# Monitor de loss: tensor(121507.7891, grad_fn=<SqrtBackward>)
# 419  de 1000
# Monitor de loss: tensor(121501.2500, grad_fn=<SqrtBackward>)
# 420  de 1000
# Monitor de loss: tensor(121494.3516, grad_fn=<SqrtBackward>)
# 421  de 1000
# Monitor de loss: tensor(121487.8359, grad_fn=<SqrtBackward>)
# 422  de 1000
# Monitor de loss: tensor(121481.1719, grad_fn=<SqrtBackward>)
# 423  de 1000
# Monitor de loss: tensor(121475.0703, grad_fn=<SqrtBackward>)
# 424  de 1000
# Monitor de loss: tensor(121468.2578, grad_fn=<SqrtBackward>)
# 425  de 1000
# Monitor de loss: tensor(121462.3828, grad_fn=<SqrtBackward>)
# 426  de 1000
# Monitor de loss: tensor(121455.1953, grad_fn=<SqrtBackward>)
# 427  de 1000
# Monitor de loss: tensor(121448.7656, grad_fn=<SqrtBackward>)
# 428  de 1000
# Monitor de loss: tensor(121442.7500, grad_fn=<SqrtBackward>)
# 429  de 1000
# Monitor de loss: tensor(121436.8516, grad_fn=<SqrtBackward>)
# 430  de 1000
# Monitor de loss: tensor(121430.7109, grad_fn=<SqrtBackward>)
# 431  de 1000
# Monitor de loss: tensor(121426.0938, grad_fn=<SqrtBackward>)
# 432  de 1000
# Monitor de loss: tensor(121419.8828, grad_fn=<SqrtBackward>)
# 433  de 1000
# Monitor de loss: tensor(121413.1172, grad_fn=<SqrtBackward>)
# 434  de 1000
# Monitor de loss: tensor(121406.8359, grad_fn=<SqrtBackward>)
# 435  de 1000
# Monitor de loss: tensor(121400.3984, grad_fn=<SqrtBackward>)
# 436  de 1000
# Monitor de loss: tensor(121394.8828, grad_fn=<SqrtBackward>)
# 437  de 1000
# Monitor de loss: tensor(121388.2969, grad_fn=<SqrtBackward>)
# 438  de 1000
# Monitor de loss: tensor(121382.7812, grad_fn=<SqrtBackward>)
# 439  de 1000
# Monitor de loss: tensor(121376.6250, grad_fn=<SqrtBackward>)
# 440  de 1000
# Monitor de loss: tensor(121371.0625, grad_fn=<SqrtBackward>)
# 441  de 1000
# Monitor de loss: tensor(121365.3438, grad_fn=<SqrtBackward>)
# 442  de 1000
# Monitor de loss: tensor(121359.8594, grad_fn=<SqrtBackward>)
# 443  de 1000
# Monitor de loss: tensor(121354.0156, grad_fn=<SqrtBackward>)
# 444  de 1000
# Monitor de loss: tensor(121347.8672, grad_fn=<SqrtBackward>)
# 445  de 1000
# Monitor de loss: tensor(121341.4922, grad_fn=<SqrtBackward>)
# 446  de 1000
# Monitor de loss: tensor(121335.5781, grad_fn=<SqrtBackward>)
# 447  de 1000
# Monitor de loss: tensor(121330.3672, grad_fn=<SqrtBackward>)
# 448  de 1000
# Monitor de loss: tensor(121324.5547, grad_fn=<SqrtBackward>)
# 449  de 1000
# Monitor de loss: tensor(121319.3125, grad_fn=<SqrtBackward>)
# 450  de 1000
# Monitor de loss: tensor(121314.3125, grad_fn=<SqrtBackward>)
# 451  de 1000
# Monitor de loss: tensor(121309.0469, grad_fn=<SqrtBackward>)
# 452  de 1000
# Monitor de loss: tensor(121303.1641, grad_fn=<SqrtBackward>)
# 453  de 1000
# Monitor de loss: tensor(121297.3281, grad_fn=<SqrtBackward>)
# 454  de 1000
# Monitor de loss: tensor(121292.4453, grad_fn=<SqrtBackward>)
# 455  de 1000
# Monitor de loss: tensor(121287.0156, grad_fn=<SqrtBackward>)
# 456  de 1000
# Monitor de loss: tensor(121281.8594, grad_fn=<SqrtBackward>)
# 457  de 1000
# Monitor de loss: tensor(121275.9297, grad_fn=<SqrtBackward>)
# 458  de 1000
# Monitor de loss: tensor(121270.0469, grad_fn=<SqrtBackward>)
# 459  de 1000
# Monitor de loss: tensor(121264.1406, grad_fn=<SqrtBackward>)
# 460  de 1000
# Monitor de loss: tensor(121258.8672, grad_fn=<SqrtBackward>)
# 461  de 1000
# Monitor de loss: tensor(121252.1484, grad_fn=<SqrtBackward>)
# 462  de 1000
# Monitor de loss: tensor(121246.5312, grad_fn=<SqrtBackward>)
# 463  de 1000
# Monitor de loss: tensor(121241.0469, grad_fn=<SqrtBackward>)
# 464  de 1000
# Monitor de loss: tensor(121235.8203, grad_fn=<SqrtBackward>)
# 465  de 1000
# Monitor de loss: tensor(121229.8047, grad_fn=<SqrtBackward>)
# 466  de 1000
# Monitor de loss: tensor(121223.8047, grad_fn=<SqrtBackward>)
# 467  de 1000
# Monitor de loss: tensor(121218., grad_fn=<SqrtBackward>)
# 468  de 1000
# Monitor de loss: tensor(121212.6016, grad_fn=<SqrtBackward>)
# 469  de 1000
# Monitor de loss: tensor(121206.6953, grad_fn=<SqrtBackward>)
# 470  de 1000
# Monitor de loss: tensor(121201.7031, grad_fn=<SqrtBackward>)
# 471  de 1000
# Monitor de loss: tensor(121196.2656, grad_fn=<SqrtBackward>)
# 472  de 1000
# Monitor de loss: tensor(121191.0781, grad_fn=<SqrtBackward>)
# 473  de 1000
# Monitor de loss: tensor(121185.4609, grad_fn=<SqrtBackward>)
# 474  de 1000
# Monitor de loss: tensor(121180.7188, grad_fn=<SqrtBackward>)
# 475  de 1000
# Monitor de loss: tensor(121175.3516, grad_fn=<SqrtBackward>)
# 476  de 1000
# Monitor de loss: tensor(121169.9688, grad_fn=<SqrtBackward>)
# 477  de 1000
# Monitor de loss: tensor(121165.0312, grad_fn=<SqrtBackward>)
# 478  de 1000
# Monitor de loss: tensor(121160.2109, grad_fn=<SqrtBackward>)
# 479  de 1000
# Monitor de loss: tensor(121155.6094, grad_fn=<SqrtBackward>)
# 480  de 1000
# Monitor de loss: tensor(121151.1094, grad_fn=<SqrtBackward>)
# 481  de 1000
# Monitor de loss: tensor(121145.3984, grad_fn=<SqrtBackward>)
# 482  de 1000
# Monitor de loss: tensor(121140.1094, grad_fn=<SqrtBackward>)
# 483  de 1000
# Monitor de loss: tensor(121134.7656, grad_fn=<SqrtBackward>)
# 484  de 1000
# Monitor de loss: tensor(121128.9062, grad_fn=<SqrtBackward>)
# 485  de 1000
# Monitor de loss: tensor(121124.1484, grad_fn=<SqrtBackward>)
# 486  de 1000
# Monitor de loss: tensor(121118.4766, grad_fn=<SqrtBackward>)
# 487  de 1000
# Monitor de loss: tensor(121113.3984, grad_fn=<SqrtBackward>)
# 488  de 1000
# Monitor de loss: tensor(121107.6406, grad_fn=<SqrtBackward>)
# 489  de 1000
# Monitor de loss: tensor(121102.1406, grad_fn=<SqrtBackward>)
# 490  de 1000
# Monitor de loss: tensor(121097.1641, grad_fn=<SqrtBackward>)
# 491  de 1000
# Monitor de loss: tensor(121092.0703, grad_fn=<SqrtBackward>)
# 492  de 1000
# Monitor de loss: tensor(121086.8125, grad_fn=<SqrtBackward>)
# 493  de 1000
# Monitor de loss: tensor(121081.6016, grad_fn=<SqrtBackward>)
# 494  de 1000
# Monitor de loss: tensor(121075.8203, grad_fn=<SqrtBackward>)
# 495  de 1000
# Monitor de loss: tensor(121069.4453, grad_fn=<SqrtBackward>)
# 496  de 1000
# Monitor de loss: tensor(121064.7578, grad_fn=<SqrtBackward>)
# 497  de 1000
# Monitor de loss: tensor(121060.1562, grad_fn=<SqrtBackward>)
# 498  de 1000
# Monitor de loss: tensor(121054.6484, grad_fn=<SqrtBackward>)
# 499  de 1000
# Monitor de loss: tensor(121048.9375, grad_fn=<SqrtBackward>)
# 500  de 1000
# Monitor de loss: tensor(121044.1719, grad_fn=<SqrtBackward>)
# 501  de 1000
# Monitor de loss: tensor(121039.2109, grad_fn=<SqrtBackward>)
# 502  de 1000
# Monitor de loss: tensor(121033.9453, grad_fn=<SqrtBackward>)
# 503  de 1000
# Monitor de loss: tensor(121029.2031, grad_fn=<SqrtBackward>)
# 504  de 1000
# Monitor de loss: tensor(121023.7109, grad_fn=<SqrtBackward>)
# 505  de 1000
# Monitor de loss: tensor(121019.2344, grad_fn=<SqrtBackward>)
# 506  de 1000
# Monitor de loss: tensor(121014.2266, grad_fn=<SqrtBackward>)
# 507  de 1000
# Monitor de loss: tensor(121008.7656, grad_fn=<SqrtBackward>)
# 508  de 1000
# Monitor de loss: tensor(121003.1641, grad_fn=<SqrtBackward>)
# 509  de 1000
# Monitor de loss: tensor(120998.0078, grad_fn=<SqrtBackward>)
# 510  de 1000
# Monitor de loss: tensor(120993.0703, grad_fn=<SqrtBackward>)
# 511  de 1000
# Monitor de loss: tensor(120988.2188, grad_fn=<SqrtBackward>)
# 512  de 1000
# Monitor de loss: tensor(120983.2422, grad_fn=<SqrtBackward>)
# 513  de 1000
# Monitor de loss: tensor(120977.7031, grad_fn=<SqrtBackward>)
# 514  de 1000
# Monitor de loss: tensor(120972.4375, grad_fn=<SqrtBackward>)
# 515  de 1000
# Monitor de loss: tensor(120967.3672, grad_fn=<SqrtBackward>)
# 516  de 1000
# Monitor de loss: tensor(120962.9141, grad_fn=<SqrtBackward>)
# 517  de 1000
# Monitor de loss: tensor(120957.3281, grad_fn=<SqrtBackward>)
# 518  de 1000
# Monitor de loss: tensor(120952.2656, grad_fn=<SqrtBackward>)
# 519  de 1000
# Monitor de loss: tensor(120947.1172, grad_fn=<SqrtBackward>)
# 520  de 1000
# Monitor de loss: tensor(120942.8672, grad_fn=<SqrtBackward>)
# 521  de 1000
# Monitor de loss: tensor(120937.5625, grad_fn=<SqrtBackward>)
# 522  de 1000
# Monitor de loss: tensor(120932.6875, grad_fn=<SqrtBackward>)
# 523  de 1000
# Monitor de loss: tensor(120927.9766, grad_fn=<SqrtBackward>)
# 524  de 1000
# Monitor de loss: tensor(120923.1328, grad_fn=<SqrtBackward>)
# 525  de 1000
# Monitor de loss: tensor(120918.6953, grad_fn=<SqrtBackward>)
# 526  de 1000
# Monitor de loss: tensor(120912.8203, grad_fn=<SqrtBackward>)
# 527  de 1000
# Monitor de loss: tensor(120908.3203, grad_fn=<SqrtBackward>)
# 528  de 1000
# Monitor de loss: tensor(120904.2266, grad_fn=<SqrtBackward>)
# 529  de 1000
# Monitor de loss: tensor(120899.6484, grad_fn=<SqrtBackward>)
# 530  de 1000
# Monitor de loss: tensor(120894.5078, grad_fn=<SqrtBackward>)
# 531  de 1000
# Monitor de loss: tensor(120889.6562, grad_fn=<SqrtBackward>)
# 532  de 1000
# Monitor de loss: tensor(120885.1250, grad_fn=<SqrtBackward>)
# 533  de 1000
# Monitor de loss: tensor(120881.1094, grad_fn=<SqrtBackward>)
# 534  de 1000
# Monitor de loss: tensor(120876.6094, grad_fn=<SqrtBackward>)
# 535  de 1000
# Monitor de loss: tensor(120872.1953, grad_fn=<SqrtBackward>)
# 536  de 1000
# Monitor de loss: tensor(120867.8828, grad_fn=<SqrtBackward>)
# 537  de 1000
# Monitor de loss: tensor(120862.5234, grad_fn=<SqrtBackward>)
# 538  de 1000
# Monitor de loss: tensor(120857.1250, grad_fn=<SqrtBackward>)
# 539  de 1000
# Monitor de loss: tensor(120852.4531, grad_fn=<SqrtBackward>)
# 540  de 1000
# Monitor de loss: tensor(120847.8516, grad_fn=<SqrtBackward>)
# 541  de 1000
# Monitor de loss: tensor(120843.7656, grad_fn=<SqrtBackward>)
# 542  de 1000
# Monitor de loss: tensor(120839.4062, grad_fn=<SqrtBackward>)
# 543  de 1000
# Monitor de loss: tensor(120834.2656, grad_fn=<SqrtBackward>)
# 544  de 1000
# Monitor de loss: tensor(120829.6562, grad_fn=<SqrtBackward>)
# 545  de 1000
# Monitor de loss: tensor(120824.1641, grad_fn=<SqrtBackward>)
# 546  de 1000
# Monitor de loss: tensor(120819.1250, grad_fn=<SqrtBackward>)
# 547  de 1000
# Monitor de loss: tensor(120815.0234, grad_fn=<SqrtBackward>)
# 548  de 1000
# Monitor de loss: tensor(120811.1016, grad_fn=<SqrtBackward>)
# 549  de 1000
# Monitor de loss: tensor(120805.8594, grad_fn=<SqrtBackward>)
# 550  de 1000
# Monitor de loss: tensor(120800.5625, grad_fn=<SqrtBackward>)
# 551  de 1000
# Monitor de loss: tensor(120795.1875, grad_fn=<SqrtBackward>)
# 552  de 1000
# Monitor de loss: tensor(120790.8672, grad_fn=<SqrtBackward>)
# 553  de 1000
# Monitor de loss: tensor(120785.9766, grad_fn=<SqrtBackward>)
# 554  de 1000
# Monitor de loss: tensor(120781.1094, grad_fn=<SqrtBackward>)
# 555  de 1000
# Monitor de loss: tensor(120776.1094, grad_fn=<SqrtBackward>)
# 556  de 1000
# Monitor de loss: tensor(120771.3281, grad_fn=<SqrtBackward>)
# 557  de 1000
# Monitor de loss: tensor(120766.6328, grad_fn=<SqrtBackward>)
# 558  de 1000
# Monitor de loss: tensor(120762.0703, grad_fn=<SqrtBackward>)
# 559  de 1000
# Monitor de loss: tensor(120757.4453, grad_fn=<SqrtBackward>)
# 560  de 1000
# Monitor de loss: tensor(120752.4141, grad_fn=<SqrtBackward>)
# 561  de 1000
# Monitor de loss: tensor(120747.5156, grad_fn=<SqrtBackward>)
# 562  de 1000
# Monitor de loss: tensor(120742.6641, grad_fn=<SqrtBackward>)
# 563  de 1000
# Monitor de loss: tensor(120738.5000, grad_fn=<SqrtBackward>)
# 564  de 1000
# Monitor de loss: tensor(120733.3359, grad_fn=<SqrtBackward>)
# 565  de 1000
# Monitor de loss: tensor(120728.3828, grad_fn=<SqrtBackward>)
# 566  de 1000
# Monitor de loss: tensor(120723.9453, grad_fn=<SqrtBackward>)
# 567  de 1000
# Monitor de loss: tensor(120719.1875, grad_fn=<SqrtBackward>)
# 568  de 1000
# Monitor de loss: tensor(120714.3516, grad_fn=<SqrtBackward>)
# 569  de 1000
# Monitor de loss: tensor(120709.2734, grad_fn=<SqrtBackward>)
# 570  de 1000
# Monitor de loss: tensor(120704.4922, grad_fn=<SqrtBackward>)
# 571  de 1000
# Monitor de loss: tensor(120699.7422, grad_fn=<SqrtBackward>)
# 572  de 1000
# Monitor de loss: tensor(120695.6016, grad_fn=<SqrtBackward>)
# 573  de 1000
# Monitor de loss: tensor(120690.4297, grad_fn=<SqrtBackward>)
# 574  de 1000
# Monitor de loss: tensor(120685.4766, grad_fn=<SqrtBackward>)
# 575  de 1000
# Monitor de loss: tensor(120681.3281, grad_fn=<SqrtBackward>)
# 576  de 1000
# Monitor de loss: tensor(120675.6484, grad_fn=<SqrtBackward>)
# 577  de 1000
# Monitor de loss: tensor(120671.8906, grad_fn=<SqrtBackward>)
# 578  de 1000
# Monitor de loss: tensor(120667.9141, grad_fn=<SqrtBackward>)
# 579  de 1000
# Monitor de loss: tensor(120663.0859, grad_fn=<SqrtBackward>)
# 580  de 1000
# Monitor de loss: tensor(120658.0234, grad_fn=<SqrtBackward>)
# 581  de 1000
# Monitor de loss: tensor(120653.6484, grad_fn=<SqrtBackward>)
# 582  de 1000
# Monitor de loss: tensor(120648.7344, grad_fn=<SqrtBackward>)
# 583  de 1000
# Monitor de loss: tensor(120643.8438, grad_fn=<SqrtBackward>)
# 584  de 1000
# Monitor de loss: tensor(120638.9844, grad_fn=<SqrtBackward>)
# 585  de 1000
# Monitor de loss: tensor(120634.3125, grad_fn=<SqrtBackward>)
# 586  de 1000
# Monitor de loss: tensor(120629.5938, grad_fn=<SqrtBackward>)
# 587  de 1000
# Monitor de loss: tensor(120625.1484, grad_fn=<SqrtBackward>)
# 588  de 1000
# Monitor de loss: tensor(120620.8203, grad_fn=<SqrtBackward>)
# 589  de 1000
# Monitor de loss: tensor(120616.0391, grad_fn=<SqrtBackward>)
# 590  de 1000
# Monitor de loss: tensor(120611.6641, grad_fn=<SqrtBackward>)
# 591  de 1000
# Monitor de loss: tensor(120606.7500, grad_fn=<SqrtBackward>)
# 592  de 1000
# Monitor de loss: tensor(120602., grad_fn=<SqrtBackward>)
# 593  de 1000
# Monitor de loss: tensor(120598.1328, grad_fn=<SqrtBackward>)
# 594  de 1000
# Monitor de loss: tensor(120592.9922, grad_fn=<SqrtBackward>)
# 595  de 1000
# Monitor de loss: tensor(120588.7109, grad_fn=<SqrtBackward>)
# 596  de 1000
# Monitor de loss: tensor(120584.0156, grad_fn=<SqrtBackward>)
# 597  de 1000
# Monitor de loss: tensor(120579.4062, grad_fn=<SqrtBackward>)
# 598  de 1000
# Monitor de loss: tensor(120574.2656, grad_fn=<SqrtBackward>)
# 599  de 1000
# Monitor de loss: tensor(120569.3984, grad_fn=<SqrtBackward>)
# 600  de 1000
# Monitor de loss: tensor(120565.2969, grad_fn=<SqrtBackward>)
# 601  de 1000
# Monitor de loss: tensor(120561.6953, grad_fn=<SqrtBackward>)
# 602  de 1000
# Monitor de loss: tensor(120556.8594, grad_fn=<SqrtBackward>)
# 603  de 1000
# Monitor de loss: tensor(120551.4297, grad_fn=<SqrtBackward>)
# 604  de 1000
# Monitor de loss: tensor(120547.8750, grad_fn=<SqrtBackward>)
# 605  de 1000
# Monitor de loss: tensor(120543.2891, grad_fn=<SqrtBackward>)
# 606  de 1000
# Monitor de loss: tensor(120538.1719, grad_fn=<SqrtBackward>)
# 607  de 1000
# Monitor de loss: tensor(120533.7500, grad_fn=<SqrtBackward>)
# 608  de 1000
# Monitor de loss: tensor(120530.1562, grad_fn=<SqrtBackward>)
# 609  de 1000
# Monitor de loss: tensor(120526.1797, grad_fn=<SqrtBackward>)
# 610  de 1000
# Monitor de loss: tensor(120521.3594, grad_fn=<SqrtBackward>)
# 611  de 1000
# Monitor de loss: tensor(120517.0078, grad_fn=<SqrtBackward>)
# 612  de 1000
# Monitor de loss: tensor(120512.5625, grad_fn=<SqrtBackward>)
# 613  de 1000
# Monitor de loss: tensor(120508.0781, grad_fn=<SqrtBackward>)
# 614  de 1000
# Monitor de loss: tensor(120504.1328, grad_fn=<SqrtBackward>)
# 615  de 1000
# Monitor de loss: tensor(120500.3984, grad_fn=<SqrtBackward>)
# 616  de 1000
# Monitor de loss: tensor(120496.3203, grad_fn=<SqrtBackward>)
# 617  de 1000
# Monitor de loss: tensor(120491.6016, grad_fn=<SqrtBackward>)
# 618  de 1000
# Monitor de loss: tensor(120487.3203, grad_fn=<SqrtBackward>)
# 619  de 1000
# Monitor de loss: tensor(120483.2109, grad_fn=<SqrtBackward>)
# 620  de 1000
# Monitor de loss: tensor(120479.0078, grad_fn=<SqrtBackward>)
# 621  de 1000
# Monitor de loss: tensor(120475.4297, grad_fn=<SqrtBackward>)
# 622  de 1000
# Monitor de loss: tensor(120471.3594, grad_fn=<SqrtBackward>)
# 623  de 1000
# Monitor de loss: tensor(120465.8906, grad_fn=<SqrtBackward>)
# 624  de 1000
# Monitor de loss: tensor(120461.0859, grad_fn=<SqrtBackward>)
# 625  de 1000
# Monitor de loss: tensor(120456.7969, grad_fn=<SqrtBackward>)
# 626  de 1000
# Monitor de loss: tensor(120452.3047, grad_fn=<SqrtBackward>)
# 627  de 1000
# Monitor de loss: tensor(120448.3203, grad_fn=<SqrtBackward>)
# 628  de 1000
# Monitor de loss: tensor(120444.3984, grad_fn=<SqrtBackward>)
# 629  de 1000
# Monitor de loss: tensor(120440.6406, grad_fn=<SqrtBackward>)
# 630  de 1000
# Monitor de loss: tensor(120436.4375, grad_fn=<SqrtBackward>)
# 631  de 1000
# Monitor de loss: tensor(120432.1797, grad_fn=<SqrtBackward>)
# 632  de 1000
# Monitor de loss: tensor(120427.0703, grad_fn=<SqrtBackward>)
# 633  de 1000
# Monitor de loss: tensor(120423.4062, grad_fn=<SqrtBackward>)
# 634  de 1000
# Monitor de loss: tensor(120418.9453, grad_fn=<SqrtBackward>)
# 635  de 1000
# Monitor de loss: tensor(120414.3516, grad_fn=<SqrtBackward>)
# 636  de 1000
# Monitor de loss: tensor(120410.4844, grad_fn=<SqrtBackward>)
# 637  de 1000
# Monitor de loss: tensor(120405.9609, grad_fn=<SqrtBackward>)
# 638  de 1000
# Monitor de loss: tensor(120402.1094, grad_fn=<SqrtBackward>)
# 639  de 1000
# Monitor de loss: tensor(120397.3594, grad_fn=<SqrtBackward>)
# 640  de 1000
# Monitor de loss: tensor(120392.5703, grad_fn=<SqrtBackward>)
# 641  de 1000
# Monitor de loss: tensor(120388.2500, grad_fn=<SqrtBackward>)
# 642  de 1000
# Monitor de loss: tensor(120384.1016, grad_fn=<SqrtBackward>)
# 643  de 1000
# Monitor de loss: tensor(120379.8750, grad_fn=<SqrtBackward>)
# 644  de 1000
# Monitor de loss: tensor(120375.6328, grad_fn=<SqrtBackward>)
# 645  de 1000
# ...
# 785  de 1000
# Monitor de loss: tensor(119762.0859, grad_fn=<SqrtBackward>)
# 786  de 1000
# Monitor de loss: tensor(119757.7109, grad_fn=<SqrtBackward>)
# 787  de 1000
# Monitor de loss: tensor(119753.5703, grad_fn=<SqrtBackward>)
# 788  de 1000
# Monitor de loss: tensor(119749.6016, grad_fn=<SqrtBackward>)
# 789  de 1000
# Monitor de loss: tensor(119745.6875, grad_fn=<SqrtBackward>)
# 790  de 1000
# Monitor de loss: tensor(119741.7969, grad_fn=<SqrtBackward>)
# 791  de 1000
# Monitor de loss: tensor(119737.7109, grad_fn=<SqrtBackward>)
# 792  de 1000
# Monitor de loss: tensor(119734.2031, grad_fn=<SqrtBackward>)
# 793  de 1000
# Monitor de loss: tensor(119730.1875, grad_fn=<SqrtBackward>)
# 794  de 1000
# Monitor de loss: tensor(119725.9922, grad_fn=<SqrtBackward>)
# 795  de 1000
# Monitor de loss: tensor(119721.8203, grad_fn=<SqrtBackward>)
# 796  de 1000
# Monitor de loss: tensor(119717.4297, grad_fn=<SqrtBackward>)
# 797  de 1000
# Monitor de loss: tensor(119713.3438, grad_fn=<SqrtBackward>)
# 798  de 1000
# Monitor de loss: tensor(119709.8594, grad_fn=<SqrtBackward>)
# 799  de 1000
# Monitor de loss: tensor(119705.4062, grad_fn=<SqrtBackward>)
# 800  de 1000
# Monitor de loss: tensor(119702.0391, grad_fn=<SqrtBackward>)
# 801  de 1000
# Monitor de loss: tensor(119698.7500, grad_fn=<SqrtBackward>)
# 802  de 1000
# Monitor de loss: tensor(119694.4609, grad_fn=<SqrtBackward>)
# 803  de 1000
# Monitor de loss: tensor(119690.5781, grad_fn=<SqrtBackward>)
# 804  de 1000
# Monitor de loss: tensor(119686.9922, grad_fn=<SqrtBackward>)
# 805  de 1000
# Monitor de loss: tensor(119683.4375, grad_fn=<SqrtBackward>)
# 806  de 1000
# Monitor de loss: tensor(119679.8516, grad_fn=<SqrtBackward>)
# 807  de 1000
# Monitor de loss: tensor(119675.2969, grad_fn=<SqrtBackward>)
# 808  de 1000
# Monitor de loss: tensor(119671.2188, grad_fn=<SqrtBackward>)
# 809  de 1000
# Monitor de loss: tensor(119666.3750, grad_fn=<SqrtBackward>)
# 810  de 1000
# Monitor de loss: tensor(119662.2656, grad_fn=<SqrtBackward>)
# 811  de 1000
# Monitor de loss: tensor(119658.5703, grad_fn=<SqrtBackward>)
# 812  de 1000
# Monitor de loss: tensor(119655.3594, grad_fn=<SqrtBackward>)
# 813  de 1000
# Monitor de loss: tensor(119650.5859, grad_fn=<SqrtBackward>)
# 814  de 1000
# Monitor de loss: tensor(119647.0781, grad_fn=<SqrtBackward>)
# 815  de 1000
# Monitor de loss: tensor(119643.1797, grad_fn=<SqrtBackward>)
# 816  de 1000
# Monitor de loss: tensor(119638.2344, grad_fn=<SqrtBackward>)
# 817  de 1000
# Monitor de loss: tensor(119635.0312, grad_fn=<SqrtBackward>)
# 818  de 1000
# Monitor de loss: tensor(119631.1172, grad_fn=<SqrtBackward>)
# 819  de 1000
# Monitor de loss: tensor(119627.5859, grad_fn=<SqrtBackward>)
# 820  de 1000
# Monitor de loss: tensor(119623.9844, grad_fn=<SqrtBackward>)
# 821  de 1000
# Monitor de loss: tensor(119620.4922, grad_fn=<SqrtBackward>)
# 822  de 1000
# Monitor de loss: tensor(119616.3672, grad_fn=<SqrtBackward>)
# 823  de 1000
# Monitor de loss: tensor(119612.2422, grad_fn=<SqrtBackward>)
# 824  de 1000
# Monitor de loss: tensor(119608.6172, grad_fn=<SqrtBackward>)
# 825  de 1000
# Monitor de loss: tensor(119605.8516, grad_fn=<SqrtBackward>)
# 826  de 1000
# Monitor de loss: tensor(119603.0156, grad_fn=<SqrtBackward>)
# 827  de 1000
# Monitor de loss: tensor(119599.3672, grad_fn=<SqrtBackward>)
# 828  de 1000
# Monitor de loss: tensor(119596.1641, grad_fn=<SqrtBackward>)
# 829  de 1000
# Monitor de loss: tensor(119593., grad_fn=<SqrtBackward>)
# 830  de 1000
# Monitor de loss: tensor(119589.3203, grad_fn=<SqrtBackward>)
# 831  de 1000
# Monitor de loss: tensor(119586.4766, grad_fn=<SqrtBackward>)
# 832  de 1000
# Monitor de loss: tensor(119582.9609, grad_fn=<SqrtBackward>)
# 833  de 1000
# Monitor de loss: tensor(119578.7031, grad_fn=<SqrtBackward>)
# 834  de 1000
# Monitor de loss: tensor(119575.5781, grad_fn=<SqrtBackward>)
# 835  de 1000
# Monitor de loss: tensor(119571.5859, grad_fn=<SqrtBackward>)
# 836  de 1000
# Monitor de loss: tensor(119569.2188, grad_fn=<SqrtBackward>)
# 837  de 1000
# Monitor de loss: tensor(119565.5312, grad_fn=<SqrtBackward>)
# 838  de 1000
# Monitor de loss: tensor(119561.9531, grad_fn=<SqrtBackward>)
# 839  de 1000
# Monitor de loss: tensor(119557.5703, grad_fn=<SqrtBackward>)
# 840  de 1000
# Monitor de loss: tensor(119553.3438, grad_fn=<SqrtBackward>)
# 841  de 1000
# Monitor de loss: tensor(119549.0234, grad_fn=<SqrtBackward>)
# 842  de 1000
# Monitor de loss: tensor(119544.8203, grad_fn=<SqrtBackward>)
# 843  de 1000
# Monitor de loss: tensor(119541.7422, grad_fn=<SqrtBackward>)
# 844  de 1000
# Monitor de loss: tensor(119538.3750, grad_fn=<SqrtBackward>)
# 845  de 1000
# Monitor de loss: tensor(119534.7734, grad_fn=<SqrtBackward>)
# 846  de 1000
# Monitor de loss: tensor(119531.5703, grad_fn=<SqrtBackward>)
# 847  de 1000
# Monitor de loss: tensor(119527.7734, grad_fn=<SqrtBackward>)
# 848  de 1000
# Monitor de loss: tensor(119523.8906, grad_fn=<SqrtBackward>)
# 849  de 1000
# Monitor de loss: tensor(119520.6250, grad_fn=<SqrtBackward>)
# 850  de 1000
# Monitor de loss: tensor(119517.7734, grad_fn=<SqrtBackward>)
# 851  de 1000
# Monitor de loss: tensor(119514.1172, grad_fn=<SqrtBackward>)
# 852  de 1000
# Monitor de loss: tensor(119511.0625, grad_fn=<SqrtBackward>)
# 853  de 1000
# Monitor de loss: tensor(119507.3281, grad_fn=<SqrtBackward>)
# 854  de 1000
# Monitor de loss: tensor(119504.2031, grad_fn=<SqrtBackward>)
# 855  de 1000
# Monitor de loss: tensor(119501.0156, grad_fn=<SqrtBackward>)
# 856  de 1000
# Monitor de loss: tensor(119497.7734, grad_fn=<SqrtBackward>)
# 857  de 1000
# Monitor de loss: tensor(119494.9141, grad_fn=<SqrtBackward>)
# 858  de 1000
# Monitor de loss: tensor(119491.0312, grad_fn=<SqrtBackward>)
# 859  de 1000
# Monitor de loss: tensor(119487.0312, grad_fn=<SqrtBackward>)
# 860  de 1000
# Monitor de loss: tensor(119483.4766, grad_fn=<SqrtBackward>)
# 861  de 1000
# Monitor de loss: tensor(119480.4141, grad_fn=<SqrtBackward>)
# 862  de 1000
# Monitor de loss: tensor(119477.2969, grad_fn=<SqrtBackward>)
# 863  de 1000
# Monitor de loss: tensor(119474.0547, grad_fn=<SqrtBackward>)
# 864  de 1000
# Monitor de loss: tensor(119470.5391, grad_fn=<SqrtBackward>)
# 865  de 1000
# Monitor de loss: tensor(119468.0781, grad_fn=<SqrtBackward>)
# 866  de 1000
# Monitor de loss: tensor(119464.7969, grad_fn=<SqrtBackward>)
# 867  de 1000
# Monitor de loss: tensor(119462.2500, grad_fn=<SqrtBackward>)
# 868  de 1000
# Monitor de loss: tensor(119458.9375, grad_fn=<SqrtBackward>)
# 869  de 1000
# Monitor de loss: tensor(119455.9453, grad_fn=<SqrtBackward>)
# 870  de 1000
# Monitor de loss: tensor(119452.9297, grad_fn=<SqrtBackward>)
# 871  de 1000
# Monitor de loss: tensor(119449.5469, grad_fn=<SqrtBackward>)
# 872  de 1000
# Monitor de loss: tensor(119446.6328, grad_fn=<SqrtBackward>)
# 873  de 1000
# Monitor de loss: tensor(119443.6016, grad_fn=<SqrtBackward>)
# 874  de 1000
# Monitor de loss: tensor(119439.6875, grad_fn=<SqrtBackward>)
# 875  de 1000
# Monitor de loss: tensor(119436.6875, grad_fn=<SqrtBackward>)
# 876  de 1000
# Monitor de loss: tensor(119433.6562, grad_fn=<SqrtBackward>)
# 877  de 1000
# Monitor de loss: tensor(119430.7188, grad_fn=<SqrtBackward>)
# 878  de 1000
# Monitor de loss: tensor(119428.4609, grad_fn=<SqrtBackward>)
# 879  de 1000
# Monitor de loss: tensor(119426.1016, grad_fn=<SqrtBackward>)
# 880  de 1000
# Monitor de loss: tensor(119423.0469, grad_fn=<SqrtBackward>)
# 881  de 1000
# Monitor de loss: tensor(119419.1328, grad_fn=<SqrtBackward>)
# 882  de 1000
# Monitor de loss: tensor(119416.2422, grad_fn=<SqrtBackward>)
# 883  de 1000
# Monitor de loss: tensor(119412.5547, grad_fn=<SqrtBackward>)
# 884  de 1000
# Monitor de loss: tensor(119410.7266, grad_fn=<SqrtBackward>)
# 885  de 1000
# Monitor de loss: tensor(119406.7188, grad_fn=<SqrtBackward>)
# 886  de 1000
# Monitor de loss: tensor(119403.3281, grad_fn=<SqrtBackward>)
# 887  de 1000
# Monitor de loss: tensor(119399.6875, grad_fn=<SqrtBackward>)
# 888  de 1000
# Monitor de loss: tensor(119395.9531, grad_fn=<SqrtBackward>)
# 889  de 1000
# Monitor de loss: tensor(119392.9062, grad_fn=<SqrtBackward>)
# 890  de 1000
# Monitor de loss: tensor(119389.2969, grad_fn=<SqrtBackward>)
# 891  de 1000
# Monitor de loss: tensor(119386.6797, grad_fn=<SqrtBackward>)
# 892  de 1000
# Monitor de loss: tensor(119382.6016, grad_fn=<SqrtBackward>)
# 893  de 1000
# Monitor de loss: tensor(119380.7578, grad_fn=<SqrtBackward>)
# 894  de 1000
# Monitor de loss: tensor(119377.4141, grad_fn=<SqrtBackward>)
# 895  de 1000
# Monitor de loss: tensor(119374.6797, grad_fn=<SqrtBackward>)
# 896  de 1000
# Monitor de loss: tensor(119371.9766, grad_fn=<SqrtBackward>)
# 897  de 1000
# Monitor de loss: tensor(119369.1875, grad_fn=<SqrtBackward>)
# 898  de 1000
# Monitor de loss: tensor(119365.8750, grad_fn=<SqrtBackward>)
# 899  de 1000
# Monitor de loss: tensor(119362.2734, grad_fn=<SqrtBackward>)
# 900  de 1000
# Monitor de loss: tensor(119359.8828, grad_fn=<SqrtBackward>)
# 901  de 1000
# Monitor de loss: tensor(119357.2344, grad_fn=<SqrtBackward>)
# 902  de 1000
# Monitor de loss: tensor(119355.1250, grad_fn=<SqrtBackward>)
# 903  de 1000
# Monitor de loss: tensor(119351.7656, grad_fn=<SqrtBackward>)
# 904  de 1000
# Monitor de loss: tensor(119349., grad_fn=<SqrtBackward>)
# 905  de 1000
# Monitor de loss: tensor(119346., grad_fn=<SqrtBackward>)
# 906  de 1000
# Monitor de loss: tensor(119343.7266, grad_fn=<SqrtBackward>)
# 907  de 1000
# Monitor de loss: tensor(119340.8828, grad_fn=<SqrtBackward>)
# 908  de 1000
# Monitor de loss: tensor(119338.4922, grad_fn=<SqrtBackward>)
# 909  de 1000
# Monitor de loss: tensor(119335.7891, grad_fn=<SqrtBackward>)
# 910  de 1000
# Monitor de loss: tensor(119333.3984, grad_fn=<SqrtBackward>)
# 911  de 1000
# Monitor de loss: tensor(119331.1250, grad_fn=<SqrtBackward>)
# 912  de 1000
# Monitor de loss: tensor(119328.4922, grad_fn=<SqrtBackward>)
# 913  de 1000
# Monitor de loss: tensor(119326.3906, grad_fn=<SqrtBackward>)
# 914  de 1000
# Monitor de loss: tensor(119324.4766, grad_fn=<SqrtBackward>)
# 915  de 1000
# Monitor de loss: tensor(119321.3594, grad_fn=<SqrtBackward>)
# 916  de 1000
# Monitor de loss: tensor(119318.5625, grad_fn=<SqrtBackward>)
# 917  de 1000
# Monitor de loss: tensor(119315.6328, grad_fn=<SqrtBackward>)
# 918  de 1000
# Monitor de loss: tensor(119312.5781, grad_fn=<SqrtBackward>)
# 919  de 1000
# Monitor de loss: tensor(119311.2344, grad_fn=<SqrtBackward>)
# 920  de 1000
# Monitor de loss: tensor(119309.1094, grad_fn=<SqrtBackward>)
# 921  de 1000
# Monitor de loss: tensor(119306.0391, grad_fn=<SqrtBackward>)
# 922  de 1000
# Monitor de loss: tensor(119303.4219, grad_fn=<SqrtBackward>)
# 923  de 1000
# Monitor de loss: tensor(119301.1172, grad_fn=<SqrtBackward>)
# 924  de 1000
# Monitor de loss: tensor(119298.7578, grad_fn=<SqrtBackward>)
# 925  de 1000
# Monitor de loss: tensor(119296.4531, grad_fn=<SqrtBackward>)
# 926  de 1000
# Monitor de loss: tensor(119294.2969, grad_fn=<SqrtBackward>)
# 927  de 1000
# Monitor de loss: tensor(119291.4766, grad_fn=<SqrtBackward>)
# 928  de 1000
# Monitor de loss: tensor(119289.2266, grad_fn=<SqrtBackward>)
# 929  de 1000
# Monitor de loss: tensor(119286.8828, grad_fn=<SqrtBackward>)
# 930  de 1000
# Monitor de loss: tensor(119284.4375, grad_fn=<SqrtBackward>)
# 931  de 1000
# Monitor de loss: tensor(119281.6094, grad_fn=<SqrtBackward>)
# 932  de 1000
# Monitor de loss: tensor(119279.3438, grad_fn=<SqrtBackward>)
# 933  de 1000
# Monitor de loss: tensor(119276.2969, grad_fn=<SqrtBackward>)
# 934  de 1000
# Monitor de loss: tensor(119274.5312, grad_fn=<SqrtBackward>)
# 935  de 1000
# Monitor de loss: tensor(119272.8203, grad_fn=<SqrtBackward>)
# 936  de 1000
# Monitor de loss: tensor(119270.0312, grad_fn=<SqrtBackward>)
# 937  de 1000
# Monitor de loss: tensor(119268.1562, grad_fn=<SqrtBackward>)
# 938  de 1000
# Monitor de loss: tensor(119266.5000, grad_fn=<SqrtBackward>)
# 939  de 1000
# Monitor de loss: tensor(119264.7031, grad_fn=<SqrtBackward>)
# 940  de 1000
# Monitor de loss: tensor(119262.4609, grad_fn=<SqrtBackward>)
# 941  de 1000
# Monitor de loss: tensor(119260.6562, grad_fn=<SqrtBackward>)
# 942  de 1000
# Monitor de loss: tensor(119258.7734, grad_fn=<SqrtBackward>)
# 943  de 1000
# Monitor de loss: tensor(119256.7969, grad_fn=<SqrtBackward>)
# 944  de 1000
# Monitor de loss: tensor(119254.7734, grad_fn=<SqrtBackward>)
# 945  de 1000
# Monitor de loss: tensor(119252.7578, grad_fn=<SqrtBackward>)
# 946  de 1000
# Monitor de loss: tensor(119251.7500, grad_fn=<SqrtBackward>)
# 947  de 1000
# Monitor de loss: tensor(119249.1797, grad_fn=<SqrtBackward>)
# 948  de 1000
# Monitor de loss: tensor(119247.3906, grad_fn=<SqrtBackward>)
# 949  de 1000
# Monitor de loss: tensor(119245.9609, grad_fn=<SqrtBackward>)
# 950  de 1000
# Monitor de loss: tensor(119244.1719, grad_fn=<SqrtBackward>)
# 951  de 1000
# Monitor de loss: tensor(119242.1875, grad_fn=<SqrtBackward>)
# 952  de 1000
# Monitor de loss: tensor(119241.4922, grad_fn=<SqrtBackward>)
# 953  de 1000
# Monitor de loss: tensor(119239.6328, grad_fn=<SqrtBackward>)
# 954  de 1000
# Monitor de loss: tensor(119237.3047, grad_fn=<SqrtBackward>)
# 955  de 1000
# Monitor de loss: tensor(119234.7188, grad_fn=<SqrtBackward>)
# 956  de 1000
# Monitor de loss: tensor(119232.0234, grad_fn=<SqrtBackward>)
# 957  de 1000
# Monitor de loss: tensor(119230.8516, grad_fn=<SqrtBackward>)
# 958  de 1000
# Monitor de loss: tensor(119229.3672, grad_fn=<SqrtBackward>)
# 959  de 1000
# Monitor de loss: tensor(119228.2031, grad_fn=<SqrtBackward>)
# 960  de 1000
# Monitor de loss: tensor(119226.3047, grad_fn=<SqrtBackward>)
# 961  de 1000
# Monitor de loss: tensor(119225.0078, grad_fn=<SqrtBackward>)
# 962  de 1000
# Monitor de loss: tensor(119224.2891, grad_fn=<SqrtBackward>)
# 963  de 1000
# Monitor de loss: tensor(119221.9062, grad_fn=<SqrtBackward>)
# 964  de 1000
# Monitor de loss: tensor(119221.0547, grad_fn=<SqrtBackward>)
# 965  de 1000
# Monitor de loss: tensor(119218.5312, grad_fn=<SqrtBackward>)
# 966  de 1000
# Monitor de loss: tensor(119216.5078, grad_fn=<SqrtBackward>)
# 967  de 1000
# Monitor de loss: tensor(119214.3047, grad_fn=<SqrtBackward>)
# 968  de 1000
# Monitor de loss: tensor(119211.9141, grad_fn=<SqrtBackward>)
# 969  de 1000
# Monitor de loss: tensor(119210.0781, grad_fn=<SqrtBackward>)
# 970  de 1000
# Monitor de loss: tensor(119207.7266, grad_fn=<SqrtBackward>)
# 971  de 1000
# Monitor de loss: tensor(119206.0938, grad_fn=<SqrtBackward>)
# 972  de 1000
# Monitor de loss: tensor(119204., grad_fn=<SqrtBackward>)
# 973  de 1000
# Monitor de loss: tensor(119202.3203, grad_fn=<SqrtBackward>)
# 974  de 1000
# Monitor de loss: tensor(119200.2344, grad_fn=<SqrtBackward>)
# 975  de 1000
# Monitor de loss: tensor(119198.3672, grad_fn=<SqrtBackward>)
# 976  de 1000
# Monitor de loss: tensor(119196.6406, grad_fn=<SqrtBackward>)
# 977  de 1000
# Monitor de loss: tensor(119194.9219, grad_fn=<SqrtBackward>)
# 978  de 1000
# Monitor de loss: tensor(119193.6797, grad_fn=<SqrtBackward>)
# 979  de 1000
# Monitor de loss: tensor(119192.3672, grad_fn=<SqrtBackward>)
# 980  de 1000
# Monitor de loss: tensor(119190.3516, grad_fn=<SqrtBackward>)
# 981  de 1000
# Monitor de loss: tensor(119188.9844, grad_fn=<SqrtBackward>)
# 982  de 1000
# Monitor de loss: tensor(119187.2344, grad_fn=<SqrtBackward>)
# 983  de 1000
# Monitor de loss: tensor(119185.4062, grad_fn=<SqrtBackward>)
# 984  de 1000
# Monitor de loss: tensor(119183.2969, grad_fn=<SqrtBackward>)
# 985  de 1000
# Monitor de loss: tensor(119180.7656, grad_fn=<SqrtBackward>)
# 986  de 1000
# Monitor de loss: tensor(119178.6484, grad_fn=<SqrtBackward>)
# 987  de 1000
# Monitor de loss: tensor(119176.5938, grad_fn=<SqrtBackward>)
# 988  de 1000
# Monitor de loss: tensor(119175.2266, grad_fn=<SqrtBackward>)
# 989  de 1000
# Monitor de loss: tensor(119174.4766, grad_fn=<SqrtBackward>)
# 990  de 1000
# Monitor de loss: tensor(119173.2188, grad_fn=<SqrtBackward>)
# 991  de 1000
# Monitor de loss: tensor(119172.0859, grad_fn=<SqrtBackward>)
# 992  de 1000
# Monitor de loss: tensor(119170.8281, grad_fn=<SqrtBackward>)
# 993  de 1000
# Monitor de loss: tensor(119169.7422, grad_fn=<SqrtBackward>)
# 994  de 1000
# Monitor de loss: tensor(119168.8750, grad_fn=<SqrtBackward>)
# 995  de 1000
# Monitor de loss: tensor(119167.2656, grad_fn=<SqrtBackward>)
# 996  de 1000
# Monitor de loss: tensor(119165.3281, grad_fn=<SqrtBackward>)
# 997  de 1000
# Monitor de loss: tensor(119164.3828, grad_fn=<SqrtBackward>)
# 998  de 1000
# Monitor de loss: tensor(119163.0078, grad_fn=<SqrtBackward>)
# 999  de 1000
# Monitor de loss: tensor(119161.4297, grad_fn=<SqrtBackward>)
# 1000  de 1000
# Monitor de loss: tensor(119160.2422, grad_fn=<SqrtBackward>)

# %%
prediction_test = torch.exp(net(X_test_tensor))

# %%
prediction_test_np = prediction_test.detach().numpy()

# %%
from sklearn.metrics import mean_squared_error
y_test = data_test.values[:, -1]
np.sqrt(mean_squared_error(y_test, prediction_test_np))
# Out:
# 117355.70388876511
